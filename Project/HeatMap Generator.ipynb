# %%
import numpy as np 
from pandas import *

SuperIndex = ['LR']
Index= ['0.1','0.01','0.001']
Cols = ['0', '1e-5', '1e-4']
n = [[0.8657, 0.8672, 0.8495], 
     [0.8711, 0.8712, 0.8701], 
     [0.8700, 0.8701, 0.8664]]
df = DataFrame(n, index= Index, columns=Cols)
df
# Out:
#             0    1e-5    1e-4
# 0.1    0.8657  0.8672  0.8495
# 0.01   0.8711  0.8712  0.8701
# 0.001  0.8700  0.8701  0.8664

# %%
import matplotlib.pyplot as plt
from pandas import DataFrame
import seaborn as sns

sns.heatmap(df, annot=True,fmt=".4g", vmin=0.84, vmax=0.89)
plt.title("CNN Accuracy on EMNIST")
plt.ylabel('learning rate')
plt.xlabel('weight decay')
fig = plt.figure()
plt.show()
